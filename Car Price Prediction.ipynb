# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
car = pd.read_csv("/home/mert/Downloads/Car details v3.csv")
car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
car.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
car.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# # DATA CLEANİNG

# %%
car.dropna(inplace=True)

# %%
car["mileage"]=car["mileage"].str.replace("kmpl"," ").str.replace(",","").str.replace("km/kg","")
car["engine"]=car["engine"].str.replace("CC"," ")
car["max_power"]=car["max_power"].str.replace("bhp"," ")

car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine max_power  \
# 0  Individual       Manual   First Owner   23.4    1248        74
# 1  Individual       Manual  Second Owner  21.14    1498    103.52
# 2  Individual       Manual   Third Owner   17.7    1497        78
# 3  Individual       Manual   First Owner   23.0    1396        90
# 4  Individual       Manual   First Owner   16.1    1298      88.2
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
car["mileage"]=car["mileage"].astype(float)
car["engine"]=car["engine"].astype(float)
car["max_power"]=car["max_power"].astype(float)
car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %% [markdown]
# # 1. Fuel Type

# %%
sns.barplot(x='fuel',y='selling_price',data=car,palette='spring')
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %% [markdown]
# # 2. Seller Type

# %%
sns.barplot(x='seller_type',y='selling_price',data=car,palette='spring')
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %% [markdown]
# # 3. Transmission Type

# %%
sns.barplot(x='transmission',y='selling_price',data=car,palette='spring')
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %% [markdown]
# # 4. Owner Type

# %%
fig = plt.figure(figsize=[10,4])
sns.barplot(x='owner',y='selling_price',data=car,palette='spring')
# Out:
# <AxesSubplot:xlabel='owner', ylabel='selling_price'>

# %% [markdown]
# # 1. Km Driven

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='km_driven',y='selling_price',data=car)

# %% [markdown]
# # 2.Mileage

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='mileage',y='selling_price',data=car)

# %% [markdown]
# # 3. Engine

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='engine',y='selling_price',data=car)

# %% [markdown]
# # 4. Max power

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='max_power',y='selling_price',data=car)

# %% [markdown]
# # 5.Car Age

# %%
car['Car_Age']=2022- car['year']
car.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00
# 4  Individual       Manual   First Owner    16.10  1298.0      88.20
#
#                      torque  seats  Car_Age
# 0            190Nm@ 2000rpm    5.0        8
# ...

# %%
plt.figure(figsize=(10,10))
sns.regplot(x='Car_Age',y='selling_price',data=car)
# Out:
# <AxesSubplot:xlabel='Car_Age', ylabel='selling_price'>

# %% [markdown]
# # Categorical Features To Numeric Type

# %%
car = pd.get_dummies(car,columns = ["fuel","seller_type","transmission"],drop_first=True)
car.drop(columns=['year'],inplace=True)
car.head()
# Out:
#                            name  selling_price  km_driven         owner  \
# 0        Maruti Swift Dzire VDI         450000     145500   First Owner
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000  Second Owner
# 2      Honda City 2017-2020 EXi         158000     140000   Third Owner
# 3     Hyundai i20 Sportz Diesel         225000     127000   First Owner
# 4        Maruti Swift VXI BSIII         130000     120000   First Owner
#
#    mileage  engine  max_power                    torque  seats  Car_Age  \
# 0    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0        8
# 1    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0        8
# 2    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0       16
# 3    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0       12
# 4    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0       15
#
#    fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# ...

# %%
sns.pairplot(car)

# %% [markdown]
# # Correlation HeatMap

# %%
correlations = car.corr()

indx=correlations.index
plt.figure(figsize=(26,22))
sns.heatmap(car[indx].corr(),annot=True,cmap="Reds")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
car_train,car_test = train_test_split(car, test_size=0.3, random_state=100)

# %%
car.head()
# Out:
#                            name  selling_price  km_driven         owner  \
# 0        Maruti Swift Dzire VDI         450000     145500   First Owner
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000  Second Owner
# 2      Honda City 2017-2020 EXi         158000     140000   Third Owner
# 3     Hyundai i20 Sportz Diesel         225000     127000   First Owner
# 4        Maruti Swift VXI BSIII         130000     120000   First Owner
#
#    mileage  engine  max_power                    torque  seats  Car_Age  \
# 0    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0        8
# 1    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0        8
# 2    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0       16
# 3    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0       12
# 4    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0       15
#
#    fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
var=["selling_price",'km_driven','Car_Age',"mileage","engine","max_power"]

car_train[var]=scaler.fit_transform(car_train[var])
car_test[var]=scaler.transform(car_test[var])

X_test=car_test.drop(columns=['name','selling_price',"owner","seats","torque"],axis=1)
y_test=car_test['selling_price']

X_train=car_train.drop(columns=['name','selling_price',"owner","seats","torque"],axis=1)
y_train=car_train['selling_price']

# %%
X_test
# Out:
#       km_driven   mileage    engine  max_power   Car_Age  fuel_Diesel  \
# 7406   0.501123  1.578348  0.073826   0.196975  0.260908            1
# 3896  -0.731664  0.915448 -0.914378  -0.684697 -0.521533            0
# 4806   0.336752 -1.797533  1.419759   0.794814  0.260908            1
# 6915   0.665495 -0.636230  0.069873  -0.078757 -0.260719            0
# 4930   0.172380 -0.803183 -1.313612  -1.523906  3.129857            0
# ...         ...       ...       ...        ...       ...          ...
# 1304   0.353189  0.777957 -0.127768  -0.078757  0.000094            1
# 5198   0.336752  0.630646 -0.523049  -0.797560  0.000094            0
# 2876   0.049101  0.964552  1.034359   1.632906  0.260908            1
# 818    0.336752  0.080684 -1.313612  -1.579779  1.304162            0
# 2297  -0.320735 -0.837555  2.099643  -0.822703  0.260908            1
#
#       fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 7406         0            0                       1
# ...

# %% [markdown]
# # 2. Creating and Training the Model¶

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#bestfit line
print(lm.intercept_)
# Out:
# 0.8424291314228053

# %%
temp=car.drop(columns=['name','selling_price',"owner","seats","torque"])
temp.head()
# Out:
#    km_driven  mileage  engine  max_power  Car_Age  fuel_Diesel  fuel_LPG  \
# 0     145500    23.40  1248.0      74.00        8            1         0
# 1     120000    21.14  1498.0     103.52        8            1         0
# 2     140000    17.70  1497.0      78.00       16            0         0
# 3     127000    23.00  1396.0      90.00       12            1         0
# 4     120000    16.10  1298.0      88.20       15            0         0
#
#    fuel_Petrol  seller_type_Individual  seller_type_Trustmark Dealer  \
# 0            0                       1                             0
# 1            0                       1                             0
# 2            1                       1                             0
# 3            0                       1                             0
# 4            1                       1                             0
#
#    transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# ...

# %%
coeff_df = pd.DataFrame(lm.coef_,temp.columns,columns=['Coefficient'])
coeff_df
# Out:
#                               Coefficient
# km_driven                       -0.064669
# mileage                          0.063055
# engine                           0.000929
# max_power                        0.584762
# Car_Age                         -0.166087
# fuel_Diesel                     -0.008024
# fuel_LPG                         0.259487
# fuel_Petrol                     -0.075442
# seller_type_Individual          -0.331353
# seller_type_Trustmark Dealer    -0.429447
# transmission_Manual             -0.594425

# %% [markdown]
# # 4. Predictions from our Model

# %%
predictions=lm.predict(X_test)


fig = plt.figure()

fig.suptitle('y_test vs predictions')


plt.xlabel('y_test')


plt.ylabel('predcitions')
plt.scatter(y_test,predictions)

# %%
fig=plt.figure(figsize=(8,8))
  
sns.distplot((y_test-predictions),bins=20)

fig.suptitle('Residual Analysis', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Residual Analysis')

# %% [markdown]
# # 5. Regression Evaluation Metrics

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.3472997319907133
# MSE: 0.33421167267972984
# RMSE: 0.5781104329448915

# %%
R2 = metrics.r2_score(y_test,predictions)
R2
# Out:
# 0.6726773932067646
